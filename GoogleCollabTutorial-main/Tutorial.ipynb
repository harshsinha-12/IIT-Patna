# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsinha-12/GoogleCollabTutorial/blob/main/Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I'm indenting next
#
#
# > Indented block
#
#
# 1.   List item
#
# ---
#
# [link text](https://google.com)
# 2.   List item

# %% [markdown]
# # New Section
#
# **bold text**
#
# *italicized text*
#
#
#
# ```
# # This is formatted as code
# for i in range(10):
# print(i)
#
# > [Indented block]
# (https://www.google.com)
#
#
# ```
#
#
# > Indented block
#
#
#
# 1.   List item
# 2.   List item
#
#
#
# *   List item
# *   List item
#
#
#
#
# ---
#
# ⏰

# %% [markdown]
# $ x = \frac{1}{2} $
#
# # for mathematical expressions use dollar $ $ \frac{a}{b}
#
# latex mathematical symbols
#
# ± 	\pm       |∓ \mp	  |×	\times   | ÷	\div
# ∗	\ast      |⋆ \star	  | ∘	\circ	  | ⋅	\cdot
# ∨	\vee      |∧ \wedge   |⊕	\oplus	 |⊗	\otimes
# ≤	\leq      |≥ \geq	  |≡	\equiv    |	⊨	\models
# ≪	\ll      |≫	\gg	     |∥	\parallel    |	∣	\mid
# ∼	\sim     |≃	\simeq	 |≈	\approx	     | ≠	\neq
# ⩽  \leqslant |⩾	\geqslant|∤	\nmid	     | ≮	\nless
# ≯	\ngtr	 |⪇	\lneq	 |⪈	\gneq        |	⊊	\subsetneq
# ⊢	\vdash	 |∈	\in	     |∉	\notin       |	∞	\infty
# ∀	\forall  |∃	\exists	 |ı	\imath	      | ȷ	\jmath
# ∂	\partial |∇	\nabla	 |ℵ	\aleph	      | ¬	\neg
# ∅	\emptyset|∠	\angle	 |∖	\backslash    |	√	\surd
# ⊣	\dashv	 |⊥	\perp	 |≍	\asymp	     |  ∙	\bullet
# …	\ldots	 |⋯	\cdots	 |⋮	\vdots	      |  ⋱	\ddots
# ⊂	\subset	 |⊆	\subseteq|∩	\cap	     |  ∪	\cup
# ⊃	\supset	 |⊇	\supseteq|⊉	\nsupseteq	 |  ⊈	\nsubseteq
#
# [link text](https://https://www.cmor-faculty.rice.edu/~heinken/latex/symbols.pdf)

# %%
a = 6
b = 7
z = a + b
z1 = b - a
z2 = a*b
z3 = a/b
print(z, z1, z2, z3)
# Out:
# 13 1 42 0.8571428571428571

# %%
import pandas as pd

pd.read_excel("drive/MyDrive/Portfolio.xlsx", index_col=0)

# FOR csv use pd.read_csv ().head()
#for xlsx pd.read_excel( ,index_col = 0)
# Out:
#                                   Current Price               Quantity  \
# Company
# NaN                                         NaN                    NaN
# NaN                                         NaN                    NaN
# Hindustan Foods                             570                    NaN
# Amrutanjan                                  700                    NaN
# Nazara tech                                 NaN                    NaN
# Affel India                                 NaN                    NaN
# Fine Organics                               NaN                    NaN
# NaN                                         NaN                    NaN
# Havells                               11 shares                    NaN
# NaN                                         NaN                    NaN
# NaN                                         NaN                    NaN
# NAME OF COMPANY                             NaN           SALES GROWTH
# ASIAN PAINTS             MARKET CAP (in crores)  SALES GROWTH % (3 YR)
# HCL TECHNOLOGIES                      291452.24                  14.79
# AVENUE SUPER.                         284894.17                  12.33
# PIDILITE INDS.                        266436.16                  15.69
# SBI LIFE INSURAN                      134251.92                  11.91
# HDFC LIFE INSUR.                      123227.82                  22.99
# DIVI'S LAB.                            113279.3                  19.46
# L & T INFOTECH                         86808.24                   21.9
# SRF                                    84567.42                  18.38
# MINDTREE                               68829.85                  20.54
# BERGER PAINTS                           57223.1                  14.45
# ICICI LOMBARD                          56076.06                  13.07
# PAGE INDUSTRIES                        55898.96                  12.81
# P I INDUSTRIES                          54541.6                  10.86
# NaN                                    52494.45                   23.1
# SOURCE: SCREENER.IN                         NaN                    NaN
# AS ON 09.11.2022                            NaN                    NaN
# NaN                                         NaN                    NaN
# Add Titan to Coffee Can                     NaN                    NaN
#
#                                     Unnamed: 3  \
# Company
# NaN                                        NaN
# NaN                                        NaN
# Hindustan Foods                            NaN
# Amrutanjan                                 NaN
# Nazara tech                                NaN
# Affel India                                NaN
# Fine Organics                              NaN
# NaN                               Total Spend:
# Havells                                    NaN
# NaN                                        NaN
# NaN                                        NaN
# NAME OF COMPANY                            NaN
# ASIAN PAINTS             SALES GROWTH % (5 YR)
# HCL TECHNOLOGIES                         14.08
# AVENUE SUPER.                            12.48
# PIDILITE INDS.                           21.09
# SBI LIFE INSURAN                         12.05
# HDFC LIFE INSUR.                         22.12
# DIVI'S LAB.                              16.37
# L & T INFOTECH                           17.13
# SRF                                      19.24
# MINDTREE                                 20.86
# BERGER PAINTS                            14.98
# ICICI LOMBARD                            13.99
# PAGE INDUSTRIES                          16.34
# P I INDUSTRIES                            12.8
# NaN                                      18.41
# SOURCE: SCREENER.IN                        NaN
# AS ON 09.11.2022                           NaN
# NaN                                        NaN
# Add Titan to Coffee Can                    NaN
#
#                                                           To BUY preferbly  \
# Company
# NaN                                                                    NaN
# NaN                                                                    NaN
# Hindustan Foods          Track daily on charts and buy when feel reason...
# Amrutanjan                        Buy when have capital or it's around 655
# Nazara tech                                           look how is it doing
# Affel India                                                            NaN
# Fine Organics                                                          NaN
# NaN                                                                  10000
# Havells                                                                NaN
# NaN                                                                    NaN
# NaN                                                             COFFEE-CAN
# NAME OF COMPANY                                                        NaN
# ASIAN PAINTS                                        SALES GROWTH % (10 YR)
# HCL TECHNOLOGIES                                                     12.17
# AVENUE SUPER.                                                        18.47
# PIDILITE INDS.                                                       30.22
# SBI LIFE INSURAN                                                     12.24
# HDFC LIFE INSUR.                                                     19.68
# DIVI'S LAB.                                                          20.14
# L & T INFOTECH                                                          17
# SRF                                                                  17.28
# MINDTREE                                                                12
# BERGER PAINTS                                                        18.58
# ICICI LOMBARD                                                         11.9
# PAGE INDUSTRIES                                                      16.27
# P I INDUSTRIES                                                       18.76
# NaN                                                                  19.68
# SOURCE: SCREENER.IN                                                    NaN
# AS ON 09.11.2022                                                       NaN
# NaN                                                                    NaN
# Add Titan to Coffee Can                                                NaN
#
#                                               Money     Unnamed: 6  \
# Company
# NaN                                             NaN            NaN
# NaN                                             NaN            NaN
# Hindustan Foods                                 NaN          10000
# Amrutanjan                                      NaN            NaN
# Nazara tech                                     NaN            NaN
# Affel India                                     NaN            NaN
# Fine Organics                                   NaN            NaN
# NaN                                             NaN            NaN
# Havells                                         NaN            NaN
# NaN                                             NaN            NaN
# NaN                                             NaN            NaN
# NAME OF COMPANY          RETURN ON CAPITAL EMPLOYED            NaN
# ASIAN PAINTS                          ROCE % (1 YR)  ROCE % (3 YR)
# HCL TECHNOLOGIES                              29.73          32.55
# AVENUE SUPER.                                  25.4          26.05
# PIDILITE INDS.                                15.75          15.87
# SBI LIFE INSURAN                              26.13          29.55
# HDFC LIFE INSUR.                              15.32          17.77
# DIVI'S LAB.                                   10.78          16.56
# L & T INFOTECH                                35.07          31.21
# SRF                                           35.72          36.53
# MINDTREE                                      23.95           19.2
# BERGER PAINTS                                 41.54          35.41
# ICICI LOMBARD                                  25.9          26.85
# PAGE INDUSTRIES                               19.19          23.84
# P I INDUSTRIES                                67.19          56.74
# NaN                                           17.33          20.07
# SOURCE: SCREENER.IN                             NaN            NaN
# AS ON 09.11.2022                                NaN            NaN
# NaN                                             NaN            NaN
# Add Titan to Coffee Can                         NaN            NaN
#
#                             Unnamed: 7      Unnamed: 8         Unnamed: 9  \
# Company
# NaN                                NaN             NaN                NaN
# NaN                                NaN             NaN                NaN
# Hindustan Foods                    NaN             NaN                NaN
# Amrutanjan                         NaN             NaN                NaN
# Nazara tech                        NaN             NaN                NaN
# Affel India                        NaN             NaN                NaN
# Fine Organics                      NaN             NaN                NaN
# NaN                                NaN             NaN                NaN
# Havells                            NaN             NaN                NaN
# NaN                                NaN             NaN                NaN
# NaN                                NaN             NaN                NaN
# NAME OF COMPANY                    NaN             NaN  VALUATION METRICS
# ASIAN PAINTS             ROCE % (5 YR)  ROCE % (10 YR)           PE RATIO
# HCL TECHNOLOGIES                 33.59           36.88              77.42
# AVENUE SUPER.                    27.45           29.57              20.59
# PIDILITE INDS.                   18.05           18.67             115.49
# SBI LIFE INSURAN                 31.67            33.6             103.34
# HDFC LIFE INSUR.                 19.35           21.01              73.55
# DIVI'S LAB.                      19.44           23.93              86.08
# L & T INFOTECH                   29.35           30.48              29.04
# SRF                              38.62           42.06              33.02
# MINDTREE                          17.2           15.46              31.32
# BERGER PAINTS                     33.4           32.85              30.22
# ICICI LOMBARD                    27.25            27.3              59.37
# PAGE INDUSTRIES                  24.01           24.02              35.64
# P I INDUSTRIES                   60.24           60.88              74.42
# NaN                              21.16           24.23              51.27
# SOURCE: SCREENER.IN                NaN             NaN                NaN
# AS ON 09.11.2022                   NaN             NaN                NaN
# NaN                                NaN             NaN                NaN
# Add Titan to Coffee Can            NaN             NaN                NaN
#
#                                Unnamed: 10  Unnamed: 11 Unnamed: 12  \
# Company
# NaN                                    NaN          NaN         NaN
# NaN                                    NaN          NaN         NaN
# Hindustan Foods                        NaN          NaN         NaN
# Amrutanjan                             NaN          NaN         NaN
# Nazara tech                            NaN          NaN         NaN
# Affel India                            NaN          NaN         NaN
# Fine Organics                          NaN          NaN         NaN
# NaN                                    NaN          NaN         NaN
# Havells                                NaN          NaN         NaN
# NaN                                    NaN          NaN         NaN
# NaN                                    NaN          NaN         NaN
# NAME OF COMPANY                        NaN          NaN         NaN
# ASIAN PAINTS             INDUSTRY PE RATIO  EV / EBITDA   PEG ratio
# HCL TECHNOLOGIES                        58        47.35        7.97
# AVENUE SUPER.                        25.67        12.74         2.2
# PIDILITE INDS.                       77.98        73.29        4.48
# SBI LIFE INSURAN                     27.41        66.41       14.59
# HDFC LIFE INSUR.                     67.14        64.03         7.7
# DIVI'S LAB.                          67.14        75.95       13.81
# L & T INFOTECH                        24.3        21.34        1.27
# SRF                                  25.67        21.49        1.73
# MINDTREE                             27.41        19.84        1.06
# BERGER PAINTS                        25.67        20.17        0.96
# ICICI LOMBARD                           58        36.31        4.23
# PAGE INDUSTRIES                      67.14        29.19        2.84
# P I INDUSTRIES                       15.13        50.65        4.93
# NaN                                  24.77        34.13        3.96
# SOURCE: SCREENER.IN                    NaN          NaN         NaN
# AS ON 09.11.2022                       NaN          NaN         NaN
# NaN                                    NaN          NaN         NaN
# Add Titan to Coffee Can                NaN          NaN         NaN
#
#                               Unnamed: 13    Unnamed: 14         Unnamed: 15  \
# Company
# NaN                                   NaN            NaN                 NaN
# NaN                                   NaN            NaN                 NaN
# Hindustan Foods                       NaN            NaN                 NaN
# Amrutanjan                            NaN            NaN                 NaN
# Nazara tech                           NaN            NaN                 NaN
# Affel India                           NaN            NaN                 NaN
# Fine Organics                         NaN            NaN                 NaN
# NaN                                   NaN            NaN                 NaN
# Havells                               NaN            NaN                 NaN
# NaN                                   NaN            NaN                 NaN
# NaN                                   NaN            NaN                 NaN
# NAME OF COMPANY                  LEVERAGE            NaN        SHAREHOLDING
# ASIAN PAINTS             DEBT (in crores)  DEBT / EQUITY  PROMOTER HOLDING %
# HCL TECHNOLOGIES                  1865.57           0.13               52.63
# AVENUE SUPER.                        6517           0.11               60.72
# PIDILITE INDS.                     710.83           0.05               74.99
# SBI LIFE INSURAN                   680.37            0.1               69.94
# HDFC LIFE INSUR.                        0              0               55.46
# DIVI'S LAB.                           950           0.08               50.32
# L & T INFOTECH                       3.29              0               51.94
# SRF                                 823.9           0.09                  74
# MINDTREE                          3833.13           0.42               50.53
# BERGER PAINTS                       613.4           0.11               60.95
# ICICI LOMBARD                     1013.53           0.26               74.99
# PAGE INDUSTRIES                        35              0               48.02
# P I INDUSTRIES                     109.91            0.1               46.12
# NaN                                 280.5           0.04               46.09
# SOURCE: SCREENER.IN                   NaN            NaN                 NaN
# AS ON 09.11.2022                      NaN            NaN                 NaN
# NaN                                   NaN            NaN                 NaN
# Add Titan to Coffee Can               NaN            NaN                 NaN
#
#                            Unnamed: 16    Unnamed: 17
# Company
# NaN                                NaN            NaN
# NaN                                NaN            NaN
# Hindustan Foods                    NaN            NaN
# Amrutanjan                         NaN            NaN
# Nazara tech                        NaN            NaN
# Affel India                        NaN            NaN
# Fine Organics                      NaN            NaN
# NaN                                NaN            NaN
# Havells                            NaN            NaN
# NaN                                NaN            NaN
# NaN                                NaN            NaN
# NAME OF COMPANY                    NaN            NaN
# ASIAN PAINTS             DII HOLDING %  FII HOLDING %
# HCL TECHNOLOGIES                  8.74          18.56
# AVENUE SUPER.                    16.52          17.17
# PIDILITE INDS.                    7.04           8.72
# SBI LIFE INSURAN                  7.73          11.34
# HDFC LIFE INSUR.                 15.65          24.33
# DIVI'S LAB.                       6.88          28.81
# L & T INFOTECH                   20.75           15.4
# SRF                               8.05           8.13
# MINDTREE                         14.03          19.21
# BERGER PAINTS                    11.82          12.06
# ICICI LOMBARD                     3.16          11.13
# PAGE INDUSTRIES                  15.89          24.07
# P I INDUSTRIES                   18.87          25.29
# NaN                                 26          16.72
# SOURCE: SCREENER.IN                NaN            NaN
# AS ON 09.11.2022                   NaN            NaN
# NaN                                NaN            NaN
# Add Titan to Coffee Can            NaN            NaN

# %%
import pandas as pd

pd.read_csv("/content/sample_data/california_housing_train.csv").head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['longitude'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_10, *['latitude'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_11, *['housing_median_age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_12, *['total_rooms'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_13, *['longitude'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_14, *['latitude'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_15, *['housing_median_age'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_16, *['total_rooms'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_17, *[[['longitude', 'latitude'], ['latitude', 'housing_median_age'], ['housing_median_age', 'total_rooms'], ['total_rooms', 'total_bedrooms']]], **{})
# chart
