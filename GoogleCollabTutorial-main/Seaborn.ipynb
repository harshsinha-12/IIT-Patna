# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsinha-12/GoogleCollabTutorial/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Data Sets for Data Visualisation/tips.csv")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Data Sets for Data Visualisation/tips.csv")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
plt.scatter(data["day"],data["tip"])
x=data["day"]
y=data["tip"]
plt.title("scatter plot")
plt.xlabel("day")
plt.ylabel("tip")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.scatterplot(x="day",y="tip",data=data,hue="sex")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(data["sex"], data["total_bill"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(data["day"], data["tip"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(data["total_bill"], data["tip"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.plot(data["total_bill"])
plt.plot(data["tip"])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.lineplot(x="sex",y="total_bill",data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.lineplot(x="day",y="tip",data=data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.lineplot(x="total_bill",y="tip",data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x="day",y="tip",data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x="day",y="tip",data=data,hue="sex")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x="day",y="tip",data=data,hue="smoker")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x="day",y="tip",data=data,hue="time")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.barplot(x="day",y="tip",data=data,hue="size")
plt.show()

# %% [markdown]
# after PDF1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['total_bill'], 5)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['total_bill'], 10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['total_bill'], 10)
sns.histplot(x = 'total_bill', data = data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 5)
sns.histplot(x = 'total_bill', data = data)
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data, bins = 10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data, bins = 10, hue = 'sex')
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data, bins = 20, hue = 'sex', kde = True)
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data, bins = 20, hue = 'day', kde = True)
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'total_bill', data = data, bins = 20, hue = 'time', kde = True)
#plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'tip', data = data, bins = 20, hue = 'time', kde = True)
#plt.show()


#KDE = Kernal Density Estimation
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'tip', data = data, bins = 20, hue = 'size', kde = True)
#plt.show()


#KDE = Kernal Density Estimation
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#plt.hist(data['total_bill'], 10, color = 'r')
sns.histplot(x = 'tip', data = data, bins = 20, kde = True)
#plt.show()


#KDE = Kernal Density Estimation
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
import seaborn as sns
sns.boxplot(data=data, x = 'tip',y='day')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

a = pd.DataFrame(data['day'].value_counts())
a.reset_index(inplace = True)
plt.pie(a['day'],labels = a['index'], autopct = '%1.2f', explode = [0.1, 0, 0, 0])
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Assuming 'data' is your DataFrame
a = pd.DataFrame(data['day'].value_counts())
a.reset_index(inplace=True)

# Create a pie chart using Plotly Express
fig = px.pie(a, names='index', values='day', title='Distribution of Days')

# Customize the appearance if needed
fig.update_traces(textinfo='percent+label', pull=[0.1, 0, 0, 0])

# Show the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is your DataFrame
a = pd.DataFrame(data['day'].value_counts())
a.reset_index(inplace=True)

# Create a pie chart using Seaborn
plt.figure(figsize=(6, 6))
sns.set(style="whitegrid")
sns.color_palette("pastel")
plt.pie(a['day'], labels=a['index'], autopct='%1.2f%%', startangle=140)

# Optional: Add a title to your pie chart
plt.title("Distribution of Days")

plt.show()
