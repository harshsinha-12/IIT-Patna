# %% [markdown]
# <a href="https://colab.research.google.com/github/harshsinha-12/GoogleCollabTutorial/blob/main/PandasTutorialHarsh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Creating a Series (1-Dimentional Data Structure)
#
# A Series can be created using any of the following
#
#
#
# 1.   Scalar Value
# 2.   Lists
# 3.
# Dictionary

# %%
series1 = pd.Series(10)
print('series1')
print(type(series1))
# Out:
# series1
# <class 'pandas.core.series.Series'>

# %%
series2 = pd.Series(10, index = [0, 1, 2, 3, 4])
print(series2)
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# dtype: int64

# %%
series3 = pd.Series(10, index= ['one', 'two', 'three', 'four'])
print(series3)
# Out:
# one      10
# two      10
# three    10
# four     10
# dtype: int64

# %%
#                 Index Name     Name
Harsh = pd.Series(10, ['Messi', 'Sachin'])
print(Harsh)
# Out:
# Messi     10
# Sachin    10
# dtype: int64

# %%
lst = [10,20,30,40,50]
#            Index  Values
Series4 = pd.Series(lst)
print(Series4)
print((Series4).describe())
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
# Series from a Dictionary
#       'Index' : 'Value'
dic = {'Name':'Harsh','Subject':'Data-Science','Topic':'Pandas'}
series5 = pd.Series(dic)
print(series5)
# Out:
# Name              Harsh
# Subject    Data-Science
# Topic            Pandas
# dtype: object

# %% [markdown]
# Creating a DataFrame (2-Dimentional Data Structure)
#
# A data frame can be created using any of the following
#
#
#
#
#
# 1.   Series
# 2.   Dictionary
# 3. Lists

# %%
#  Dataframe From list
#       Values
lst2 = [5,18,25,30,32]
df1 = pd.DataFrame(lst2)
print(df1)
print((df1).describe())
# Out:
#     0
# 0   5
# 1  18
# 2  25
# 3  30
# 4  32
#                0
# count   5.000000
# mean   22.000000
# std    10.931606
# min     5.000000
# 25%    18.000000
# 50%    25.000000
# 75%    30.000000
# max    32.000000

# %%
#  Dataframe From list of lists
#         for row 0. for row 1
lst3 = [[5,18,25],[30,32]]
#                Values         Row Left          Column Top
df2 = pd.DataFrame(lst3, index=[0,1],  columns=['two', 3, 4])
print(df2)
# Out:
#    two   3     4
# 0    5  18  25.0
# 1   30  32   NaN

# %%
#  Dataframe From Series
df3 = pd.DataFrame(series2)
print(df3)
# Out:
#     0
# 0  10
# 1  10
# 2  10
# 3  10
# 4  10

# %%
# DataFrame from Dictionary
#    Column1  Value                       Column2 Data
dic2 = {'Sport':['Cricket','Football'],'Player':['Virat Kohli','Sunil Chhetri']}
#row
df4 = pd.DataFrame(dic2)
print(df4)
# Out:
#       Sport         Player
# 0   Cricket    Virat Kohli
# 1  Football  Sunil Chhetri

# %%
# DataFrame from Dictionary of Series
# Column 1 Value
name = pd.Series(['Harsh','Sinha'])
# Column 2 Value
topic = pd.Series(['Data Science','BTech'])
# Column 1: Value. Column2: Value
dic3 = {'Name':name,'Topic':topic}
df5 = pd.DataFrame(dic3)
print(df5)
# Out:
#     Name         Topic
# 0  Harsh  Data Science
# 1  Sinha         BTech

# %%
# DataFrame from List of Dictionaries
#        Column1 Values  Column2 Values
lst4 = [{'Name':'Harsh','Topic':'Data Science'},
        {'Name':'Sinha','Topic':'BTech'}]
df6 = pd.DataFrame(lst4)
print(df6)
# Out:
#     Name         Topic
# 0  Harsh  Data Science
# 1  Sinha         BTech

# %% [markdown]
# For loading data from G-Drive:
#
#
# 1.   First Mount Drive
# 2.   Get file loction
# 3. Use the same path for assigning parameters in pandas read function

# %%
# For mounting Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# IRIS.CSV
iris = pd.read_csv("/content/drive/MyDrive/Data Sets for Data Visualisation/IRIS 2.csv")
print(iris)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Head and Tail Functions

# %%
# To access the top rows by Default value is 5
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# To access the bottom rows by Default value is 5
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['sepal_length'], **{})
# ...

# %% [markdown]
# **Selection of Row or Column**
#
# * Selection Using loc
# *   Selection Using iloc
# *   Selection Using [ ]

# %%
# Selection using [] for column
# Syntax:- variable_name[index]

iris['sepal_length']
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
# Selection using [] for column
# Syntax:- variable_name[index]

iris['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
# Selection using [] for rows
# Syntax:- variable_name[StartRange> : StopRange - 1]
iris[0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_26, *['sepal_length'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
# Selection Using loc for rows
# Syntax:- name.loc[StartRange : StopRange]
iris.loc[0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_29, *['sepal_length'], **{})
# chart
# import numpy as np
# ...

# %%
# Selection Using loc for column
# Syntax:- name.loc[index]
iris.loc[0:5,['sepal_length']]
# Out:
#    sepal_length
# 0           5.1
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0
# 5           5.4
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_40, *['sepal_length'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
# Selection according to some conditions

iris.loc[(iris.sepal_length > 5) & (iris.sepal_width < 2.5)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 81            5.5          2.4           3.7          1.0  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
# Selection Using iloc for rows
# Syntax:- name.iloc[StartRange : StopRange - 1]
iris.iloc[0:1]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa

# %%
# Selection Using iloc for column
# Syntax:- name.iloc[index]
# have to pass an integer index in the method to select a specific row/column.
# does not accept the boolean data
print(iris.iloc[0:10,0:2])
iris.iloc[0:10,0:2]
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
# 5           5.4          3.9
# 6           4.6          3.4
# 7           5.0          3.4
# 8           4.4          2.9
# 9           4.9          3.1
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
# 5           5.4          3.9
# 6           4.6          3.4
# 7           5.0          3.4
# 8           4.4          2.9
# 9           4.9          3.1
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %% [markdown]
# **To Add & Rename a column in dataframe**

# %%
arr = [ 10 , 20 , 30 , 40]
df_1= pd.DataFrame(arr, columns=['col1'])
df_1['New'] = 20   # new column with all same value
print(df_1)
df_1
# Out:
#    col1  New
# 0    10   20
# 1    20   20
# 2    30   20
# 3    40   20
#    col1  New
# 0    10   20
# 1    20   20
# 2    30   20
# 3    40   20
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1, *['col1'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
# Rename
df_1.columns = ['col11', 'col22']
print(df_1)
df_1
# Out:
#    col11  col22
# 0     10     20
# 1     20     20
# 2     30     20
# 3     40     20
#    col11  col22
# 0     10     20
# 1     20     20
# 2     30     20
# 3     40     20
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1, *['col11'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
# Rename
df_1.rename(columns = {'col22':'col2'}, inplace = True)
print(df_1)
df_1
# Out:
#    col11  col2
# 0     10    20
# 1     20    20
# 2     30    20
# 3     40    20
#    col11  col2
# 0     10    20
# 1     20    20
# 2     30    20
# 3     40    20
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_1, *['col11'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %% [markdown]
# **To Delete a Column in data frame**

# %%
# Delete a Column Using del
df_2 = df_1.copy()
del df_2['col2']
print(df_2)
df_2
# Out:
#    col11
# 0     10
# 1     20
# 2     30
# 3     40
#    col11
# 0     10
# 1     20
# 2     30
# 3     40
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_2, *['col11'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
# Delete a Column Using drop()
df_3 = df_1.copy()
df_3.drop('col11',axis=1,inplace=True)
print(df_3)
df_3
# Out:
#    col2
# 0    20
# 1    20
# 2    20
# 3    20
#    col2
# 0    20
# 1    20
# 2    20
# 3    20
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
# ...

# %%
# Delete a row Using drop()
df_4 = df_1.copy()
df_4.drop(index=[1,2],axis=0,inplace=True)
print(df_4)
df_4
# Out:
#    col11  col2
# 0     10    20
# 3     40    20
#    col11  col2
# 0     10    20
# 3     40    20
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_4, *['col11'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
# Delete NULL value Using dropna()
# Delete a row Using drop()
df_5 = pd.DataFrame([[10,20],[65,70,75]])
print(df_5)
print("-------------------")
print("After deletion of NaN row")
df_6 = df_5.dropna()  # By default axis=0
print(df_6)
print("-------------------")
print("After deletion of NaN column")
df_7 = df_5.dropna(axis=1)
print(df_7)
# Out:
#     0   1     2
# 0  10  20   NaN
# 1  65  70  75.0
# -------------------
# After deletion of NaN row
#     0   1     2
# 1  65  70  75.0
# -------------------
# After deletion of NaN column
#     0   1
# 0  10  20
# 1  65  70

# %% [markdown]
# **Replace Empty/Null Values**

# %%
# Filling value Using fillna()
df_8 = df_5.copy()
df_8.fillna(100,inplace=True)
print(df_8)
df_8
# Out:
#     0   1      2
# 0  10  20  100.0
# 1  65  70   75.0
#     0   1      2
# 0  10  20  100.0
# 1  65  70   75.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8, *[0], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %% [markdown]
# **Adding Values to existing DataFrame**

# %%
# Adding value Using loc
df_9 = df_5.copy()
df_9.loc[len(df_9.index)] = [1,None,2]
print(df_9)
df_9
# Out:
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_9, *[0], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
# ...

# %%
# Adding value Using append
df_10 = df_5[0:1].copy()
print(df_10)
print("-------------------")
df_11 = df_5[1:].copy()
print(df_11)
print("-------------------")
df_10 = pd.concat([df_10,df_11])
print(df_10)
# Out:
#     0   1   2
# 0  10  20 NaN
# -------------------
#     0   1     2
# 1  65  70  75.0
# -------------------
#     0   1     2
# 0  10  20   NaN
# 1  65  70  75.0

# %% [markdown]
# **Replace Empty/Null Values**

# %%
# Filling value Using fillna()
df_8 = df_5.copy()
df_8.fillna(100,inplace=True)
print(df_8)
# Out:
#     0   1      2
# 0  10  20  100.0
# 1  65  70   75.0

# %% [markdown]
# **Adding Values to existing Data Frames**

# %%
# Adding value Using loc
df_9 = df_5.copy()
df_9.loc[len(df_9.index)] = [1,None,2]
print(df_9)
# Out:
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0

# %%
# Adding value Using append
df_10 = df_5[0:1].copy()
print(df_10)
print("-------------------")
df_11 = df_5[1:].copy()
print(df_11)
print("-------------------")
df_10 = pd.concat([df_10,df_11])
print(df_10)
# Out:
#     0   1   2
# 0  10  20 NaN
# -------------------
#     0   1     2
# 1  65  70  75.0
# -------------------
#     0   1     2
# 0  10  20   NaN
# 1  65  70  75.0

# %% [markdown]
# **Replace Null Value using Mean, Median or Mode**

# %%
# Replacing Null with mean value
df_12 = df_9.copy()
print(df_12)
print("-------------------")
mean = df_12.loc[:,2].mean()
df_12.loc[:,2].fillna(mean, inplace=True)
print(mean)
# Out:
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0
# -------------------
# 38.5

# %%
# Replacing Null with mean value
df_12 = iris.copy()
print(df_12)
print("-------------------")
median = df_12.iloc[:,2].mean()
print("median:", median)
df_12.iloc[:,2].fillna(median, inplace=True)
print(df_12)
df_12
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# -------------------
# median: 3.758666666666666
# ...

# %%
# Replacing Null with mode value
df_13 = df_9.copy()
print(df_13)
print("-------------------")
mode = df_13.loc[:,2].mode()[0]
df_13.loc[:,2].fillna(mode, inplace=True)
print(mode)
# Out:
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0
# -------------------
# 2.0

# %%
# Replacing Null with median value
df_14 = df_9.copy()
print(df_14)
print("-------------------")
median = df_13.loc[:,2].median()
df_13.loc[:,2].fillna(median, inplace=True)
print(median)
# Out:
#       0     1     2
# 0  10.0  20.0   NaN
# 1  65.0  70.0  75.0
# 2   1.0   NaN   2.0
# -------------------
# 2.0

# %% [markdown]
# **Normalization**

# %%
# Copy the data
arr10 = [10, 20, 30, 40]
df_new = pd.DataFrame(arr10,columns = ['col1'])
arr11 = [60, 70, 80, 90]
df_new['col2'] = arr11
df_new
# Out:
#    col1  col2
# 0    10    60
# 1    20    70
# 2    30    80
# 3    40    90
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_new, *['col1'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
# Sum values of each object
df_new['col1'].sum()
# Out:
# 100

# %%
# Count non-NA/null values of each column
df_new['col1'].count()
# Out:
# 4

# %%
# Minimum value in each column
df_new['col1'].min()
# Out:
# 10

# %%
# Maximum value in each column
df_new['col1'].max()
# Out:
# 40

# %%
# Apply normalization techniques by Column 1
column = 'col1'
df_new[column] = (df_new[column] - df_new[column].min() / (df_new[column].max() - df_new[column].min()) )

print(df_new)
# Out:
#         col1  col2
# 0   9.666667    60
# 1  19.666667    70
# 2  29.666667    80
# 3  39.666667    90

# %% [markdown]
# **Min Max Feature Scaling**

# %%
# copy the data
arr10 = [ 10 , 20 , 30 , 40]
df_new= pd.DataFrame(arr10, columns=['col1'])
arr11 = [ 60 , 70 , 80 , 90]
df_new['col2'] = arr11

# apply normalization techniques by Column 1
column = 'col1'
df_new[column] = (df_new[column] - df_new[column].min()) / (df_new[column].max() - df_new[column].min())

# view normalized data
print(df_new)
df_new
# Out:
#        col1  col2
# 0  0.000000    60
# 1  0.333333    70
# 2  0.666667    80
# 3  1.000000    90
#        col1  col2
# 0  0.000000    60
# 1  0.333333    70
# 2  0.666667    80
# 3  1.000000    90
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_new, *['col1'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
# ...

# %%
(20-10)/(40-10)
# Out:
# 0.3333333333333333

# %%
column = 'col1'
df_new[column]
# Out:
# 0    0.000000
# 1    0.333333
# 2    0.666667
# 3    1.000000
# Name: col1, dtype: float64

# %%
df_new[column].min()
# Out:
# 0.0

# %%
print(df_new[column] - df_new[column].min()/30)
# Out:
# 0    0.000000
# 1    0.333333
# 2    0.666667
# 3    1.000000
# Name: col1, dtype: float64

# %% [markdown]
# **Query**
#
# Allows Boolean expressions for filtering rows

# %%
print(df_new.query('col1 > 10'))
print('----------------')
print(df_new.query('col1 > 20 and col2 < 100'))
# Out:
# Empty DataFrame
# Columns: [col1, col2]
# Index: []
# ----------------
# Empty DataFrame
# Columns: [col1, col2]
# Index: []

# %% [markdown]
# **Concatenation**

# %%
dic11 = {'Sport':['Cricket', 'Football'], 'Player' : ['Rohit Sharma', 'Sunil Chhetri']}
dic12 = {'Sport':['Cricket', 'Football'], 'Player' : ['Virat Kohli', 'Ishaan Pandita']}
df11 = pd.DataFrame(dic11)
df12 = pd.DataFrame(dic12)
print(df11)
print('-----------')
print(df12)
# Out:
#       Sport         Player
# 0   Cricket   Rohit Sharma
# 1  Football  Sunil Chhetri
# -----------
#       Sport          Player
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita

# %%
# Concatenating df11 and df12 along rows
df111 = pd.concat([df11, df12])
print(df111)
df111
# Out:
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df111, *['Sport'], **{})
# chart
# ...

# %%
df111 = pd.concat([df11, df12], ignore_index = True)
print(df111)
df111
# Out:
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 2   Cricket     Virat Kohli
# 3  Football  Ishaan Pandita
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 2   Cricket     Virat Kohli
# 3  Football  Ishaan Pandita
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df111, *['Sport'], **{})
# chart
# ...

# %%
# Concatenating df11 and df12 along rows
df111 = pd.concat([df11, df12], axis = 1)
print(df111)
# Out:
#       Sport         Player   Sport 2          Player
# 0   Cricket   Rohit Sharma   Cricket     Virat Kohli
# 1  Football  Sunil Chhetri  Football  Ishaan Pandita

# %%
df111 = pd.concat([df11, df12], ignore_index = True)
print(df111)
# Out:
#       Sport          Player   Sport 2
# 0   Cricket    Rohit Sharma       NaN
# 1  Football   Sunil Chhetri       NaN
# 2       NaN     Virat Kohli   Cricket
# 3       NaN  Ishaan Pandita  Football

# %%
# Concatenating df11 and df12 along colums
df111 = pd.concat([df11, df12], axis = 1)
print(df111)
# Out:
#       Sport         Player   Sport 2          Player
# 0   Cricket   Rohit Sharma   Cricket     Virat Kohli
# 1  Football  Sunil Chhetri  Football  Ishaan Pandita

# %%
dic11 = {'Sport':['Cricket', 'Football'], 'Player' : ['Rohit Sharma', 'Sunil Chhetri']}
dic12 = {'Sport 2':['Cricket', 'Football'], 'Player' : ['Virat Kohli', 'Ishaan Pandita']}
df11 = pd.DataFrame(dic11)
df12 = pd.DataFrame(dic12)
print(df11)
print('-----------')
print(df12)
# Out:
#       Sport         Player
# 0   Cricket   Rohit Sharma
# 1  Football  Sunil Chhetri
# -----------
#     Sport 2          Player
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita

# %%
# Concatenating df11 and df12 along rows
df111 = pd.concat([df11, df12])
print(df111)
# Out:
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita

# %%
df111 = pd.concat([df11, df12], ignore_index = True)
print(df111)
# Out:
#       Sport          Player   Sport 2
# 0   Cricket    Rohit Sharma       NaN
# 1  Football   Sunil Chhetri       NaN
# 2       NaN     Virat Kohli   Cricket
# 3       NaN  Ishaan Pandita  Football

# %%
# Only rows that have matching values in both dataframes will be included in the merged dataframe
dfll1 = pd.concat([df11, df12], join = 'inner')
print(dfll1)
dfll1
# Out:
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita
#       Sport          Player
# 0   Cricket    Rohit Sharma
# 1  Football   Sunil Chhetri
# 0   Cricket     Virat Kohli
# 1  Football  Ishaan Pandita
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(dfll1, *['Sport'], **{})
# chart
# ...

# %%
df1 = pd.DataFrame({'Name':['John', 'Tom', 'Simon', 'Jose'],
                    'Age':[5, 6, 4, 7]})
df2 = pd.DataFrame({'Name':['John', 'Tom', 'Simon', 'Jose'],
                    'Class':['Second', 'Third', 'Fifth', 'Fourth']})

df111 = pd.concat([df1, df2], join = 'outer')
print(df111)
df111
# Out:
#     Name  Age   Class
# 0   John  5.0     NaN
# 1    Tom  6.0     NaN
# 2  Simon  4.0     NaN
# 3   Jose  7.0     NaN
# 0   John  NaN  Second
# 1    Tom  NaN   Third
# 2  Simon  NaN   Fifth
# 3   Jose  NaN  Fourth
#     Name  Age   Class
# 0   John  5.0     NaN
# 1    Tom  6.0     NaN
# 2  Simon  4.0     NaN
# 3   Jose  7.0     NaN
# 0   John  NaN  Second
# 1    Tom  NaN   Third
# 2  Simon  NaN   Fifth
# 3   Jose  NaN  Fourth
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df111, *['Age'], **{})
# chart
# ...

# %% [markdown]
# Grouping

# %%
import pandas as pd

data = [("bird", "Falconiformes", 389.0),
        ("bird", "Psittaciformes", 24.0),
        ("mammal", "Carnivora", 80.2),
        ("mammal", "Primates", None),
        ("mammal", "Carnivora", 58.0)]

index = ['falcon', 'parrot', 'lion', 'monkey', 'leopard']

columns = ["class", "order", "max_speed"]

speeds = pd.DataFrame(data, index=index, columns=columns)

print(speeds)
speeds
# Out:
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0
#           class           order  max_speed
# falcon     bird   Falconiformes      389.0
# parrot     bird  Psittaciformes       24.0
# lion     mammal       Carnivora       80.2
# monkey   mammal        Primates        NaN
# leopard  mammal       Carnivora       58.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %%
grouped = speeds.groupby("class")
grouped.sum()
# Out:
# <ipython-input-13-c9818fa145e0>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped.sum()
#         max_speed
# class
# bird        413.0
# mammal      138.2
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_4, *['max_speed'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
grouped.apply(print)
# Out:
#        class           order  max_speed
# falcon  bird   Falconiformes      389.0
# parrot  bird  Psittaciformes       24.0
#           class      order  max_speed
# lion     mammal  Carnivora       80.2
# monkey   mammal   Primates        NaN
# leopard  mammal  Carnivora       58.0
# Empty DataFrame
# Columns: []
# Index: []
# No charts were generated by quickchart

# %%
print(speeds.groupby(["class","order"]).groups)
# Out:
# {('bird', 'Falconiformes'): ['falcon'], ('bird', 'Psittaciformes'): ['parrot'], ('mammal', 'Carnivora'): ['lion', 'leopard'], ('mammal', 'Primates'): ['monkey']}

# %%
print(speeds.groupby(["class","order"]).count())
speeds.groupby(["class","order"]).count()
# Out:
#                        max_speed
# class  order
# bird   Falconiformes           1
#        Psittaciformes          1
# mammal Carnivora               2
#        Primates                0
#                        max_speed
# class  order
# bird   Falconiformes           1
#        Psittaciformes          1
# mammal Carnivora               2
#        Primates                0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_6, *['max_speed'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# ...

# %% [markdown]
# **Python Lambda**
#
#
#
#
# 1.   Small anonymonous function
# 2.   can take any number of arguments, but can only have one expression
# 3. Syntax: lambda arguments: expression

# %%
# Multiply argument a with argumenyt b and return the result

x = lambda a,b : a*b
print(x(5,6))
# Out:
# 30

# %% [markdown]
# **apply()**
#
#
# *   can be applied with python lambda to execute expression
#
# OBSERVE MATRIX

# %%
data = [(3,5,7),(2,4,6),(5,8,9)]
df = pd.DataFrame(data, columns = ['A','B','C'])
print(df)
df
# Out:
#    A  B  C
# 0  3  5  7
# 1  2  4  6
# 2  5  8  9
#    A  B  C
# 0  3  5  7
# 1  2  4  6
# 2  5  8  9
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['A'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
#Apply a lambda function to each column
df2 = df.apply(lambda x:x+10)
print(df2)
df2
# Out:
#     A   B   C
# 0   9  15  17
# 1   8  14  16
# 2  11  18  19
#     A   B   C
# 0   9  15  17
# 1   8  14  16
# 2  11  18  19
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df2, *['A'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %%
#Apply a lambda function to selected column
df["A"] = df["A"] = df["A"].apply(lambda x:x-2)
print(df)
df
# Out:
#    A  B  C
# 0 -1  5  7
# 1 -2  4  6
# 2  1  8  9
#    A  B  C
# 0 -1  5  7
# 1 -2  4  6
# 2  1  8  9
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df, *['A'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...
